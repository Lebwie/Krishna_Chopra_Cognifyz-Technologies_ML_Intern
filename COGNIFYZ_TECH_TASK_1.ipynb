# %% [markdown]
# #**ML Project**

# %% [markdown]
# #**First ML-Project**

# %% [markdown]
# # Loading the DataSet

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Lebwie/Krishna_Chopra_Cognifyz-Technologies_ML_Intern/refs/heads/main/Dataset%20.csv')
df
print(df)
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karak�_y
# 9547                                   Ko��uyolu
# 9548                                 Kuru�_e��me
# 9549                                 Kuru�_e��me
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karak�_y, ��stanbul   28.977392
# 9547                               Ko��uyolu, ��stanbul   29.041297
# 9548                             Kuru�_e��me, ��stanbul   29.034640
# 9549                             Kuru�_e��me, ��stanbul   29.036019
# 9550                                    Moda, ��stanbul   29.026016
#
#        Latitude                          Cuisines  ...          Currency  \
# 0     14.565443        French, Japanese, Desserts  ...  Botswana Pula(P)
# 1     14.553708                          Japanese  ...  Botswana Pula(P)
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)
# 3     14.585318                   Japanese, Sushi  ...  Botswana Pula(P)
# 4     14.584450                  Japanese, Korean  ...  Botswana Pula(P)
# ...         ...                               ...  ...               ...
# 9546  41.022793                           Turkish  ...  Turkish Lira(TL)
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9548  41.055817            Italian, World Cuisine  ...  Turkish Lira(TL)
# 9549  41.057979                   Restaurant Cafe  ...  Turkish Lira(TL)
# 9550  40.984776                              Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 0                  Yes                  No                No
# 1                  Yes                  No                No
# 2                  Yes                  No                No
# 3                   No                  No                No
# 4                  Yes                  No                No
# ...                ...                 ...               ...
# 9546                No                  No                No
# 9547                No                  No                No
# 9548                No                  No                No
# 9549                No                  No                No
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 0                      No           3               4.8    Dark Green
# 1                      No           3               4.5    Dark Green
# 2                      No           4               4.4         Green
# 3                      No           4               4.9    Dark Green
# 4                      No           4               4.8    Dark Green
# ...                   ...         ...               ...           ...
# 9546                   No           3               4.1         Green
# 9547                   No           3               4.2         Green
# 9548                   No           4               3.7        Yellow
# 9549                   No           4               4.0         Green
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 0      Excellent   314
# 1      Excellent   591
# 2      Very Good   270
# 3      Excellent   365
# 4      Excellent   229
# ...          ...   ...
# 9546   Very Good   788
# 9547   Very Good  1034
# 9548        Good   661
# 9549   Very Good   901
# 9550   Very Good   591
#
# [9551 rows x 21 columns]

# %% [markdown]
# ## DataPreparation

# %% [markdown]
# ### Data Cleaning

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# Filling the null values to "***Unknown***"

# %% [markdown]
# ## Data Separation

# %%
# Out:
# this is x
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karak�_y
# 9547                                   Ko��uyolu
# 9548                                 Kuru�_e��me
# 9549                                 Kuru�_e��me
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karak�_y, ��stanbul   28.977392
# 9547                               Ko��uyolu, ��stanbul   29.041297
# 9548                             Kuru�_e��me, ��stanbul   29.034640
# 9549                             Kuru�_e��me, ��stanbul   29.036019
# 9550                                    Moda, ��stanbul   29.026016
#
#        Latitude                          Cuisines  Average Cost for two  \
# 0     14.565443        French, Japanese, Desserts                  1100
# 1     14.553708                          Japanese                  1200
# 2     14.581404  Seafood, Asian, Filipino, Indian                  4000
# 3     14.585318                   Japanese, Sushi                  1500
# 4     14.584450                  Japanese, Korean                  1500
# ...         ...                               ...                   ...
# 9546  41.022793                           Turkish                    80
# 9547  41.009847   World Cuisine, Patisserie, Cafe                   105
# 9548  41.055817            Italian, World Cuisine                   170
# 9549  41.057979                   Restaurant Cafe                   120
# 9550  40.984776                              Cafe                    55
#
#               Currency Has Table booking Has Online delivery  \
# 0     Botswana Pula(P)               Yes                  No
# 1     Botswana Pula(P)               Yes                  No
# 2     Botswana Pula(P)               Yes                  No
# 3     Botswana Pula(P)                No                  No
# 4     Botswana Pula(P)               Yes                  No
# ...                ...               ...                 ...
# 9546  Turkish Lira(TL)                No                  No
# 9547  Turkish Lira(TL)                No                  No
# 9548  Turkish Lira(TL)                No                  No
# 9549  Turkish Lira(TL)                No                  No
# 9550  Turkish Lira(TL)                No                  No
#
#      Is delivering now Switch to order menu  Price range Rating color  \
# 0                   No                   No            3   Dark Green
# 1                   No                   No            3   Dark Green
# 2                   No                   No            4        Green
# 3                   No                   No            4   Dark Green
# 4                   No                   No            4   Dark Green
# ...                ...                  ...          ...          ...
# 9546                No                   No            3        Green
# 9547                No                   No            3        Green
# 9548                No                   No            4       Yellow
# 9549                No                   No            4        Green
# 9550                No                   No            2        Green
#
#      Rating text  Votes
# 0      Excellent    314
# 1      Excellent    591
# 2      Very Good    270
# 3      Excellent    365
# 4      Excellent    229
# ...          ...    ...
# 9546   Very Good    788
# 9547   Very Good   1034
# 9548        Good    661
# 9549   Very Good    901
# 9550   Very Good    591
#
# [9551 rows x 20 columns]

# %% [markdown]
# ## Data Spliting

# %% [markdown]
# ## X and y Training datset

# %%
 from sklearn.model_selection import train_test_split

 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_test
# Out:
#       Restaurant ID    Restaurant Name  Country Code       City  \
# 7231         302471    Ashu Thali Wala             1  New Delhi
# 3100             67            Fa Yian             1  New Delhi
# 2354         100306             Replay             1     Jaipur
# 4147       18366025           Mr. Momo             1  New Delhi
# 5084       18489540   Pokhreli Kitchen             1  New Delhi
# ...             ...                ...           ...        ...
# 3186            525            Barista             1  New Delhi
# 8093       18381672    Cafe Coffee Day             1      Noida
# 8730           2971  Lahori Restaurant             1      Noida
# 4498       18377630   Havmor Ice Cream             1  New Delhi
# 1220       18303709        Burma Burma             1    Gurgaon
#
#                                                 Address  \
# 7231       BK 1/3, Block BK 1, Shalimar Bagh, New Delhi
# 3100  A-25/5, Middle Circle, Connaught Place, New Delhi
# 2354  SB 57, 5th Floor, Ridhi Tower, Opposite SMS St...
# 4147  Shop 41/1, Near House of Tax, Ashok Nagar, Jai...
# 5084   184, Ground Floor, Road 1, Mahipalpur, New Delhi
# ...                                                 ...
# 3186  15, Gyandeep, Main Market, Defence Colony, New...
# 8093      1st Floor, Gardens Galleria, Sector 38, Noida
# 8730  B-1/28, Central Market, Above Archies, Sector ...
# 4498  5885, 28-UA, Ground Floor, Jawajar Agar, Civil...
# 1220  Ground Floor, Shop 6, Building 8, Tower C, Cyb...
#
#                                Locality  \
# 7231                      Shalimar Bagh
# 3100                    Connaught Place
# 2354                          Tonk Road
# 4147                          Jail Road
# 5084                         Mahipalpur
# ...                                 ...
# 3186                     Defence Colony
# 8093  Gardens Galleria, Sector 38 Noida
# 8730                          Sector 50
# 4498                        Kamla Nagar
# 1220          Cyber Hub, DLF Cyber City
#
#                               Locality Verbose  Longitude   Latitude  \
# 7231                  Shalimar Bagh, New Delhi  77.168557  28.709610
# 3100                Connaught Place, New Delhi  77.217298  28.632811
# 2354                         Tonk Road, Jaipur  75.806896  26.892312
# 4147                      Jail Road, New Delhi  77.099683  28.635750
# 5084                     Mahipalpur, New Delhi  77.126449  28.546965
# ...                                        ...        ...        ...
# 3186                 Defence Colony, New Delhi  77.230142  28.573545
# 8093  Gardens Galleria, Sector 38 Noida, Noida  77.321718  28.564749
# 8730                          Sector 50, Noida  77.361983  28.570507
# 4498                    Kamla Nagar, New Delhi  77.208315  28.679521
# 1220        Cyber Hub, DLF Cyber City, Gurgaon  77.088733  28.494629
#
#                                                Cuisines  Average Cost for two  \
# 7231                                       North Indian                   250
# 3100                                            Chinese                  1200
# 2354  North Indian, Continental, Chinese, Italian, M...                  1500
# 4147                                 Fast Food, Chinese                   350
# 5084                             South Indian, Nepalese                   450
# ...                                                 ...                   ...
# 3186                                               Cafe                   650
# 8093                                               Cafe                   450
# 8730                              North Indian, Chinese                   800
# 4498                                          Ice Cream                   200
# 1220                                     Asian, Burmese                  1500
#
#                 Currency Has Table booking Has Online delivery  \
# 7231  Indian Rupees(Rs.)                No                  No
# 3100  Indian Rupees(Rs.)               Yes                  No
# 2354  Indian Rupees(Rs.)                No                  No
# 4147  Indian Rupees(Rs.)                No                  No
# 5084  Indian Rupees(Rs.)                No                  No
# ...                  ...               ...                 ...
# 3186  Indian Rupees(Rs.)                No                 Yes
# 8093  Indian Rupees(Rs.)                No                  No
# 8730  Indian Rupees(Rs.)               Yes                  No
# 4498  Indian Rupees(Rs.)                No                 Yes
# 1220  Indian Rupees(Rs.)               Yes                  No
#
#      Is delivering now Switch to order menu  Price range Rating color  \
# 7231                No                   No            1       Orange
# 3100                No                   No            3        Green
# 2354                No                   No            3        Green
# 4147                No                   No            1        White
# 5084                No                   No            1        White
# ...                ...                  ...          ...          ...
# 3186                No                   No            2       Orange
# 8093                No                   No            1        White
# 8730                No                   No            2       Orange
# 4498                No                   No            1       Yellow
# 1220                No                   No            3   Dark Green
#
#      Rating text  Votes
# 7231     Average     11
# 3100   Very Good    412
# 2354   Very Good   1121
# 4147   Not rated      1
# 5084   Not rated      1
# ...          ...    ...
# 3186     Average     73
# 8093   Not rated      3
# 8730     Average    206
# 4498        Good     20
# 1220   Excellent    563
#
# [1911 rows x 20 columns]

# %% [markdown]
# # Model Building

# %% [markdown]
# ### Lable Encoding

# %%
# Remove LabelEncoder code

# %%
import pandas as pd

# Apply one-hot encoding to all object columns in both train and test sets
x_train = pd.get_dummies(x_train, columns=x_train.select_dtypes(include='object').columns)
x_test = pd.get_dummies(x_test, columns=x_test.select_dtypes(include='object').columns)

# Align columns - crucial for consistent feature sets
x_train, x_test = x_train.align(x_test, join='outer', axis=1, fill_value=0)

# %% [markdown]
# ## Linera Regaression

# %% [markdown]
# ### Model Fitting

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train )
# Out:
# LinearRegression()

# %% [markdown]
# ### **Applying the model to make prediction**

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %% [markdown]
# **Result**

# %%
print(y_lr_train_pred)
# Out:
# [4.4        3.20000013 3.2        ... 2.69999998 3.69999999 3.80000018]

# %%
print(y_lr_test_pred)
# Out:
# [2.32690737 3.34304383 3.98467378 ... 2.34828144 4.02696646 4.82409815]

# %% [markdown]
# ### **Evaluation**

# %% [markdown]
# ### Model Performance

# %%
from sklearn.metrics import r2_score , mean_squared_error

y_train_lr_mse = mean_squared_error(y_train, y_lr_train_pred)
y_train_lr_r2 = r2_score(y_train, y_lr_train_pred)

y_test_lr_mse = mean_squared_error(y_test, y_lr_test_pred)
y_test_lr_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print('LR MSE TRAIN:', y_train_lr_mse)
print('LR MSE TEST:', y_test_lr_mse)
print('LR R2 TRAIN:', y_train_lr_r2)
print('LR R2 TEST:', y_test_lr_r2)
# Out:
# LR MSE TRAIN: 7.302564584753284e-07
# LR MSE TEST: 0.3162884180007643
# LR R2 TRAIN: 0.9999996808214724
# LR R2 TEST: 0.8650205917859294

# %% [markdown]
# ### Results Table

# %%
lr_results = pd.DataFrame(['LinearRegression', y_train_lr_mse, y_test_lr_mse, y_train_lr_r2 , y_test_lr_r2]).transpose()
lr_results.columns = ['Meathod', 'Training mse', 'Testing mse', 'Training r2' , 'Testing r2']

# %%
lr_results
# Out:
#             Meathod Training mse Testing mse Training r2 Testing r2
# 0  LinearRegression     0.000001    0.316288         1.0   0.865021

# %% [markdown]
# ## **Random Forest**

# %% [markdown]
# ### Training the Model

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth = 2 , random_state = 100)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# ### Making Predictions

# %%
rf_train_pred = rf.predict(x_train)
rf_test_pred = rf.predict(x_test)

# %% [markdown]
# **Result**

# %%
print(rf_train_pred)
# Out:
# [3.83235531 3.05582085 3.05582085 ... 3.05582085 3.83235531 3.83235531]

# %%
print(rf_test_pred)
# Out:
# [3.05582085 3.83235531 3.83235531 ... 3.05582085 3.83235531 3.83235531]

# %% [markdown]
# ### Evaluating the model

# %%
from sklearn.metrics import r2_score , mean_squared_error

rf_train_mse = mean_squared_error(y_train, rf_train_pred)
rf_train_r2 = r2_score(y_train, rf_train_pred)

rf_test_mse = mean_squared_error(y_test, rf_test_pred)
rf_test_r2 = r2_score(y_test, rf_test_pred)

# %%
print('RF MSE TRAIN:', rf_train_mse)
print('RF MSE TEST:', rf_test_mse)
print('RF R2 TRAIN:', rf_train_r2)
print('RF R2 TEST:', rf_test_r2)
# Out:
# RF MSE TRAIN: 0.1179682324492837
# RF MSE TEST: 0.11376783943388302
# RF R2 TRAIN: 0.9484387624435031
# RF R2 TEST: 0.9514483782313463

# %% [markdown]
# ### Results Table

# %%
rf_results = pd.DataFrame(['RandomForestRegressor', rf_train_mse, rf_test_mse, rf_train_r2 , rf_test_r2]).transpose()
rf_results.columns = ['Meathod', 'Training mse', 'Testing mse', 'Training r2' , 'Testing r2']

# %%
rf_results
# Out:
#                  Meathod Training mse Testing mse Training r2 Testing r2
# 0  RandomForestRegressor     0.117968    0.113768    0.948439   0.951448

# %% [markdown]
# ## RidgeRegression

# %% [markdown]
# ### Training the models

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=1.0)
ridge.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_ridge.py:254: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# Ridge()

# %% [markdown]
# ### Making Predictions

# %%
ridge_train_pred = ridge.predict(x_train)
ridge_test_pred = ridge.predict(x_test)

# %% [markdown]
# **Result**

# %%
print(ridge_train_pred)
# Out:
# [4.24864553 3.10544567 2.94018109 ... 3.15864116 3.76064022 3.70513205]

# %%
print(ridge_test_pred)
# Out:
# [3.15861023 4.10383221 4.31780731 ... 3.1922395  3.60753851 4.34476252]

# %% [markdown]
# ### Evaluating the model

# %%
#i personally like to do the test right after the train
ridge_train_mse = mean_squared_error(y_train, ridge_train_pred)
ridge_test_mse = mean_squared_error(y_test, ridge_test_pred)

ridge_train_r2 = r2_score(y_train, ridge_train_pred)
ridge_test_r2 = r2_score(y_test, ridge_test_pred)

# %%
print('RIDGE MSE TRAIN:', ridge_train_mse)
print('RIDGE MSE TEST:', ridge_test_mse)
print('RIDGE R2 TRAIN:', ridge_train_r2)
print('RIDGE R2 TEST:', ridge_test_r2)
# Out:
# RIDGE MSE TRAIN: 0.04737292021064448
# RIDGE MSE TEST: 0.04722898093641803
# RIDGE R2 TRAIN: 0.9792943715268759
# RIDGE R2 TEST: 0.97984453576376

# %% [markdown]
# ### Results Table

# %%
ridge_results = pd.DataFrame(['Ridge Regression', ridge_train_mse, ridge_test_mse, ridge_train_r2 , ridge_test_r2]).transpose()
ridge_results.columns = ['Meathod', 'Training mse', 'Testing mse', 'Training r2' , 'Testing r2']

# %%
ridge_results
# Out:
#             Meathod Training mse Testing mse Training r2 Testing r2
# 0  Ridge Regression     0.047373    0.047229    0.979294   0.979845

# %% [markdown]
# ## Lasso Regression

# %% [markdown]
# ### Training Model

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=1.0)
lasso.fit(x_train, y_train)
# Out:
# Lasso()

# %% [markdown]
# ### Making Predictions

# %%
lasso_train_pred = lasso.predict(x_train)
lasso_test_pred = lasso.predict(x_test)

# %%
lasso_train_pred
# Out:
# array([4.04174903, 2.9680003 , 1.89622984, ..., 2.94393894, 3.00467658,
#        2.00667055])

# %%
lasso_test_pred
# Out:
# array([2.94639476, 3.25703815, 3.76555754, ..., 3.10664978, 1.8937934 ,
#        2.29471286])

# %% [markdown]
# ### Evaluating the model

# %%
lasso_train_mse = mean_squared_error(y_train, lasso_train_pred)
lasso_test_mse = mean_squared_error(y_test, lasso_test_pred)

lasso_train_r2 = r2_score(y_train, lasso_train_pred)
lasso_test_r2 = r2_score(y_test, lasso_test_pred)

# %%
print('LASSO MSE TRAIN:', lasso_train_mse)
print('LASSO MSE TEST:', lasso_test_mse)
print('LASSO R2 TRAIN:', lasso_train_r2)
print('LASSO R2 TEST:', lasso_test_r2)
# Out:
# LASSO MSE TRAIN: 1.6849384443092603
# LASSO MSE TEST: 1.7189313215703035
# LASSO R2 TRAIN: 0.26355163935804493
# LASSO R2 TEST: 0.2664279836335036

# %% [markdown]
# ### Results Table

# %%
lasso_results = pd.DataFrame(['Lasso Regression', lasso_train_mse, lasso_test_mse, lasso_train_r2 , lasso_test_r2]).transpose()
lasso_results.columns = ['Meathod', 'Training mse', 'Testing mse', 'Training r2' , 'Testing r2']

# %%
lasso_results
# Out:
#             Meathod Training mse Testing mse Training r2 Testing r2
# 0  Lasso Regression     1.684938    1.718931    0.263552   0.266428

# %% [markdown]
# ## Discision Tree Regressor

# %% [markdown]
# ### Training the model

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor(random_state=100)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=100)

# %% [markdown]
# ### Making Predictions

# %%
dt_train_predict = dt.predict(x_train)
dt_test_predict = dt.predict(x_test)

# %%
dt_train_predict
# Out:
# array([4.4, 3.2, 3.2, ..., 2.7, 3.7, 3.8])

# %%
dt_test_predict
# Out:
# array([2.7, 4.3, 4.1, ..., 2.5, 3.5, 4.6])

# %% [markdown]
# ### Evaluating the model

# %%
dt_train_mse = mean_squared_error(y_train, dt_train_predict)
dt_test_mse = mean_squared_error(y_test, dt_test_predict)

dt_train_r2 = r2_score(y_train, dt_train_predict)
dt_test_r2 = r2_score(y_test, dt_test_predict)

# %%
print('DT MSE TRAIN:', dt_train_mse)
print('DT MSE TEST:', dt_test_mse)
print('DT R2 TRAIN:', dt_train_r2)
print('DT R2 TEST:', dt_test_r2)
# Out:
# DT MSE TRAIN: 2.3645176347593156e-32
# DT MSE TEST: 0.04877027734170591
# DT R2 TRAIN: 1.0
# DT R2 TEST: 0.9791867713157816

# %% [markdown]
# ### Results Table

# %%
dt_results = pd.DataFrame(['Discision Tree', dt_train_mse, dt_test_mse, dt_train_r2 , dt_test_r2]).transpose()
dt_results.columns = ['Meathod', 'Training mse', 'Testing mse', 'Training r2' , 'Testing r2']

# %%
dt_results
# Out:
#           Meathod Training mse Testing mse Training r2 Testing r2
# 0  Discision Tree          0.0     0.04877         1.0   0.979187

# %% [markdown]
# ## Elastic Net

# %% [markdown]
# ### Training the model

# %%
from sklearn.linear_model import ElasticNet

elastic_net = ElasticNet(alpha=1.0, l1_ratio=0.5)
elastic_net.fit(x_train, y_train)
# Out:
# ElasticNet()

# %% [markdown]
# ### Making Predictions

# %%
elastic_train = elastic_net.predict(x_train)
elastic_test = elastic_net.predict(x_test)

# %%
elastic_test
# Out:
# array([2.94480757, 3.25500832, 3.76182368, ..., 3.10493666, 1.89852456,
#        2.29878513])

# %%
elastic_train
# Out:
# array([4.00339742, 2.96657128, 1.90090689, ..., 2.94237076, 3.00286293,
#        2.00717024])

# %% [markdown]
# ### Evaluating the model

# %%
elastic_train_mse = mean_squared_error(y_train, elastic_train)
elastic_test_mse = mean_squared_error(y_test, elastic_test)

elastic_train_r2 = r2_score(y_train, elastic_train)
elastic_test_r2 = r2_score(y_test, elastic_test)

# %%
print('Elastic MSE TRAIN:', elastic_train_mse)
print('Elastic MSE TEST:', elastic_test_mse)
print('Elastic R2 TRAIN:', elastic_train_r2)
print('Elastic R2 TEST:', elastic_test_r2)
# Out:
# Elastic MSE TRAIN: 1.6825684349490189
# Elastic MSE TEST: 1.7164599569938026
# Elastic R2 TRAIN: 0.26458751667092284
# Elastic R2 TEST: 0.267482664453389

# %% [markdown]
# ### Results Table

# %%
elastic_results = pd.DataFrame(['Elastic Net', elastic_train_mse, elastic_test_mse, elastic_train_r2 , elastic_test_r2]).transpose()
elastic_results.columns = ['Meathod', 'Training mse', 'Testing mse', 'Training r2' , 'Testing r2']

# %%
elastic_results
# Out:
#        Meathod Training mse Testing mse Training r2 Testing r2
# 0  Elastic Net     1.682568     1.71646    0.264588   0.267483

# %% [markdown]
# ## Gradiant Boosting

# %% [markdown]
# ### Model Training

# %%
from sklearn.ensemble import GradientBoostingRegressor

model = GradientBoostingRegressor(random_state=100)
model.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=100)

# %% [markdown]
# ### Making Predictions

# %%
gb_train_pred = model.predict(x_train)
gb_test_pred = model.predict(x_test)

# %%
gb_train_pred
# Out:
# array([4.21484239, 3.04845404, 3.11811886, ..., 2.99001628, 3.60748861,
#        3.78573448])

# %%
gb_test_pred
# Out:
# array([2.98860648, 4.07408965, 4.18072455, ..., 3.05287863, 3.66752537,
#        4.63182829])

# %% [markdown]
# ### Evaluating the model

# %%
gb_train_mse = mean_squared_error(y_train, gb_train_pred)
gb_test_mse = mean_squared_error(y_test, gb_test_pred)

gb_train_r2 = r2_score(y_train, gb_train_pred)
gb_test_r2 = r2_score(y_test, gb_test_pred)

# %%
print('GB MSE TRAIN:', gb_train_mse)
print('GB MSE TEST:', gb_test_mse)
print('GB R2 TRAIN:', gb_train_r2)
print('GB R2 TEST:', gb_test_r2)
# Out:
# GB MSE TRAIN: 0.025356788443645896
# GB MSE TEST: 0.02798761416598628
# GB R2 TRAIN: 0.9889171231486007
# GB R2 TEST: 0.9880559913596348

# %% [markdown]
# results table

# %%
gb_results = pd.DataFrame(['Gradient Boosting', gb_train_mse, gb_test_mse, gb_train_r2 , gb_test_r2]).transpose()
gb_results.columns = ['Meathod', 'Training mse', 'Testing mse', 'Training r2' , 'Testing r2']

# %%
gb_results
# Out:
#              Meathod Training mse Testing mse Training r2 Testing r2
# 0  Gradient Boosting     0.025357    0.027988    0.988917   0.988056

# %% [markdown]
# ## K Nearest Neighbour Regressor

# %% [markdown]
# ### Model Training

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=42)
knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=42)

# %% [markdown]
# ### Making Predictions

# %%
knn_train_predict = knn.predict(x_train)
knn_test_predict = knn.predict(x_test)

# %%
knn_train_predict
# Out:
# array([4.19285714, 2.64761905, 2.67380952, ..., 2.60238095, 3.0952381 ,
#        0.57619048])

# %%
knn_test_predict
# Out:
# array([2.2952381 , 3.25238095, 4.2047619 , ..., 3.13333333, 0.63809524,
#        3.12857143])

# %% [markdown]
# ### Evaluation of the model

# %%
knn_train_mse = mean_squared_error(y_train, knn_train_predict)
knn_test_mse = mean_squared_error(y_test, knn_test_predict)

knn_train_r2 = r2_score(y_train, knn_train_predict)
knn_test_r2 = r2_score(y_test, knn_test_predict)

# %%
print('KNN MSE TRAIN:', knn_train_mse)
print('KNN MSE TEST:', knn_test_mse)
print('KNN R2 TRAIN:', knn_train_r2)
print('KNN R2 TEST:', knn_test_r2)
# Out:
# KNN MSE TRAIN: 1.344686798061284
# KNN MSE TEST: 1.4185091177583888
# KNN R2 TRAIN: 0.4122679131966259
# KNN R2 TEST: 0.3946363181062542

# %% [markdown]
# ### Results Table

# %%
knn_results = pd.DataFrame(['KNN', knn_train_mse, knn_test_mse, knn_train_r2 , knn_test_r2]).transpose()
knn_results.columns = (['Meathod', 'Training mse', 'Testing mse', 'Training r2' , 'Testing r2'])

# %%
knn_results
# Out:
#   Meathod Training mse Testing mse Training r2 Testing r2
# 0     KNN     1.344687    1.418509    0.412268   0.394636

# %% [markdown]
# # Comparison Table

# %%
all_results = pd.concat([lr_results,rf_results,ridge_results,lasso_results,dt_results,elastic_results, gb_results,knn_results], axis=0)
all_results.columns = (['Meathod', 'Training mse', 'Testing mse', 'Training r2' , 'Testing r2'])
all_results = all_results.reset_index(drop=True)

all_results
# Out:
#                  Meathod Training mse Testing mse Training r2 Testing r2
# 0       LinearRegression     0.000001    0.316288         1.0   0.865021
# 1  RandomForestRegressor     0.117968    0.113768    0.948439   0.951448
# 2       Ridge Regression     0.047373    0.047229    0.979294   0.979845
# 3       Lasso Regression     1.684938    1.718931    0.263552   0.266428
# 4         Discision Tree          0.0     0.04877         1.0   0.979187
# 5            Elastic Net     1.682568     1.71646    0.264588   0.267483
# 6      Gradient Boosting     0.025357    0.027988    0.988917   0.988056
# 7                    KNN     1.344687    1.418509    0.412268   0.394636

# %% [markdown]
# Here we know the most accurate model here is **Gradiant Boosting**

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Scatter Plot

# %%
import matplotlib.pyplot as plt

plt.scatter( x = y_train , y = gb_train_pred ,alpha = 0.1, color = 'red')
plt.ylabel('Predict Aggregate rating')
plt.xlabel('Experimental Aggregate rating')
plt.show()
